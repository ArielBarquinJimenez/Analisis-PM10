# %% [markdown]
# # MoneyPrinterTurbo Setup Guide
#
# This notebook will guide you through the process of setting up [MoneyPrinterTurbo](https://github.com/harry0703/MoneyPrinterTurbo).

# %% [markdown]
# ## 1. Clone Repository and Install Dependencies
#
# First, we'll clone the repository from GitHub and install all required packages:

# %%
# !git clone https://github.com/harry0703/MoneyPrinterTurbo.git
# %cd MoneyPrinterTurbo
# !pip install -q -r requirements.txt
# !pip install pyngrok --quiet
# Out:
# Cloning into 'MoneyPrinterTurbo'...
# remote: Enumerating objects: 2336, done.
# remote: Total 2336 (delta 0), reused 0 (delta 0), pack-reused 2336 (from 1)
# Receiving objects: 100% (2336/2336), 519.79 MiB | 24.93 MiB/s, done.
# Resolving deltas: 100% (1276/1276), done.
# Updating files: 100% (115/115), done.
# /content/MoneyPrinterTurbo
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 103.7 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 303.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 199.6 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 254.8 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 322.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.8/389.8 kB 160.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 209.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 275.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 290.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 167.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 118.6 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 209.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 128.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 225.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 63.8 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 81.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.27.1 requires fastapi<1.0.0,>=0.124.1, but you have fastapi 0.115.6 which is incompatible.
# google-adk 1.27.1 requires starlette<1.0.0,>=0.49.1, but you have starlette 0.41.3 which is incompatible.
# google-adk 1.27.1 requires uvicorn<1.0.0,>=0.34.0, but you have uvicorn 0.32.1 which is incompatible.
# sse-starlette 3.3.2 requires starlette>=0.49.1, but you have starlette 0.41.3 which is incompatible.

# %% [markdown]
# ## 2. Configure ngrok for Remote Access
#
# We'll use ngrok to create a secure tunnel to expose our local Streamlit server to the internet.
#
# **Important**: You need to get your authentication token from the [ngrok dashboard](https://dashboard.ngrok.com/get-started/your-authtoken) to use this service.

# %%
from pyngrok import ngrok

# Terminate any existing ngrok tunnels
ngrok.kill()

# Set your authentication token
# Replace "your_ngrok_auth_token" with your actual token
ngrok.set_auth_token("3BQF0hOFJKMKuAkbiM4cF9WwH57_7txM4MTbCwp5bmi3oGxxe")

# %% [markdown]
# ## 3. Launch Application and Generate Public URL
#
# Now we'll start the Streamlit server and create an ngrok tunnel to make it accessible online:

# %%
import subprocess
import time

print("🚀 Starting MoneyPrinterTurbo...")
# Start Streamlit server on port 8501
streamlit_proc = subprocess.Popen([
    "streamlit", "run", "./webui/Main.py", "--server.port=8501"
])

# Wait for the server to initialize
time.sleep(5)

print("🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...")
public_url = ngrok.connect(8501, bind_tls=True)

print("✅ Deployment complete! Access your MoneyPrinterTurbo at:")
print(public_url)
# Out:
# 🚀 Starting MoneyPrinterTurbo...
# 🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...
# ✅ Deployment complete! Access your MoneyPrinterTurbo at:
# NgrokTunnel: "https://antheridial-unirrigated-britney.ngrok-free.dev" -> "http://localhost:8501"
